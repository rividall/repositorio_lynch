# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

# set this so the 
# %matplotlib inline

url = 'data.csv'
    
scl = pd.read_csv(url, sep = ',')

# %%
scl.head(2)
# Out:
#    id      comunas  Delitos2017  Dineroinvertido2017  IDSE2017  Poblacion2017  \
# 0   1    Cerrillos         5.44                 2.08     68.25          14.94
# 1   2  Cerro Navia         4.05                 2.78     56.65          23.34
#
#    Delitos2020  Dineroinvertido 2020  IDSE2020  Poblacion2020
# 0        10.26                  0.61     55.80          16.90
# 1        13.91                  0.25     42.65          27.35

# %%
# get the Series of the names
x = scl.comunas
y = scl.Delitos2017
# use the Counter class from collections to create a dictionary with keys(text) and frequency
letter_counts = Counter(x)

# convert the dictionary to a DataFrame
df = pd.DataFrame.from_dict(letter_counts, orient='index')

# sort the values from the top to the least value
df = df[0].sort_values(ascending = True)[0:33]

# create the plot
df.plot(kind='bar')

# Set the title and labels
plt.xlabel('Comunas')
plt.ylabel('Delitos')
plt.title('Delitos por comuna')

# show the plot
plt.show()
